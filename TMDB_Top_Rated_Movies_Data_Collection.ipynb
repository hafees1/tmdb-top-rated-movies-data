# %%
import pandas as pd
import requests

# %%
df=pd.DataFrame()

MAX_PAGES = 500
API_KEY = "YOUR_TMDB_API_KEY"

for i in range(1, MAX_PAGES + 1):
  response = requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key={API_KEY}&language=en-US&page={i}")
  temp_df=pd.DataFrame(response.json()['results'])[['title','overview','release_date','popularity','vote_average','vote_count']]
  df=pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#                          title  \
# 0                      Swapped
# 1     The Shawshank Redemption
# 2                      Michael
# 3            Project Hail Mary
# 4                The Godfather
# ...                        ...
# 9995                   Collide
# 9996            Catch That Kid
# 9997                   Damaged
# 9998                    Popeye
# 9999                     D-Tox
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     The story of Michael Jackson, one of the most ...   2026-04-22
# 3     Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...                                                 ...          ...
# 9995  An American backpacker gets involved with a ri...   2016-06-10
# ...

# %%
df.to_csv("tmdb_top_rated_movies.csv", index=False)
